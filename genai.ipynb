# %% [markdown]
# # Movie Information ChatBot

# %% [markdown]
# ## Set-up environment

# %%
import os
import pandas as pd

# %%
import langdetect
from langdetect import DetectorFactory, detect, detect_langs

# %%
from langchain.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

# %%
# Embedding facilities
from langchain.embeddings import HuggingFaceEmbeddings
# Pipelines
from langchain import HuggingFacePipeline
from langchain.chains import RetrievalQA

# %% [markdown]
# ## Data Collection

# %%
tsv_file_paths = ['Data/name.basics.tsv', 'Data/title.basics.tsv', 'Data/title.ratings.tsv']

# %%
dfs = []
for file_path in tsv_file_paths:
    df = pd.read_csv(file_path, sep='\t')
    dfs.append(df)
# Out:
# C:\Users\Caroline\AppData\Local\Temp\ipykernel_17996\3103568006.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='\t')

# %%
df1 = dfs[0]
df2 = dfs[1]
df3 = dfs[2]

# %%
df4 = pd.read_json('Data/IMDB_reviews.json', lines=True)
df5 = pd.read_json('Data/IMDB_movie_details.json', lines=True)

# %%
df1.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                     primaryProfession                           knownForTitles
# 0        actor,miscellaneous,producer  tt0072308,tt0050419,tt0053137,tt0027125
# 1  actress,soundtrack,archive_footage  tt0037382,tt0075213,tt0117057,tt0038355
# 2   actress,music_department,producer  tt0057345,tt0049189,tt0056404,tt0054452
# 3       actor,writer,music_department  tt0072562,tt0077975,tt0080455,tt0078723
# 4               writer,director,actor  tt0050986,tt0083922,tt0050976,tt0069467

# %%
df1 = df1.assign(knownForTitles=df1['knownForTitles'].str.split(',')).explode('knownForTitles')
df1.head()
# Out:
#       nconst    primaryName birthYear deathYear  \
# 0  nm0000001   Fred Astaire      1899      1987
# 0  nm0000001   Fred Astaire      1899      1987
# 0  nm0000001   Fred Astaire      1899      1987
# 0  nm0000001   Fred Astaire      1899      1987
# 1  nm0000002  Lauren Bacall      1924      2014
#
#                     primaryProfession knownForTitles
# 0        actor,miscellaneous,producer      tt0072308
# 0        actor,miscellaneous,producer      tt0050419
# 0        actor,miscellaneous,producer      tt0053137
# 0        actor,miscellaneous,producer      tt0027125
# 1  actress,soundtrack,archive_footage      tt0037382

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22192074 entries, 0 to 13510203
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 1.2+ GB

# %%
df1.replace('\\N', pd.NA, inplace=True)

# %%
df1 = df1.dropna(subset=['knownForTitles'])

# %%
df1.isnull().sum()
# Out:
# nconst                      0
# primaryName                 8
# birthYear            20180253
# deathYear            21488173
# primaryProfession     1850675
# knownForTitles              0
# dtype: int64

# %%
df1 = df1.drop(columns=['nconst'])
df1.head()
# Out:
#      primaryName birthYear deathYear                   primaryProfession  \
# 0   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 0   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 0   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 0   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 1  Lauren Bacall      1924      2014  actress,soundtrack,archive_footage
#
#   knownForTitles
# 0      tt0072308
# 0      tt0050419
# 0      tt0053137
# 0      tt0027125
# 1      tt0037382

# %%
df2.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              5  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10790736 entries, 0 to 10790735
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 740.9+ MB

# %%
df2['isAdult'] = df2['isAdult'].replace({0: False, 1: True})

# %%
df2.replace('\\N', pd.NA, inplace=True)

# %%
df2.isnull().sum()
# Out:
# tconst                   0
# titleType                0
# primaryTitle            19
# originalTitle           19
# isAdult                  1
# startYear          1406804
# endYear           10666898
# runtimeMinutes     7443113
# genres              480417
# dtype: int64

# %%
df3.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2058
# 1  tt0000002            5.7       276
# 2  tt0000003            6.5      2015
# 3  tt0000004            5.4       179
# 4  tt0000005            6.2      2784

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440380 entries, 0 to 1440379
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1440380 non-null  object
#  1   averageRating  1440380 non-null  float64
#  2   numVotes       1440380 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.0+ MB

# %%
df3.replace('\\N', pd.NA, inplace=True)

# %%
df3.isnull().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
merging_df = pd.merge(df1, df2, left_on='knownForTitles', right_on='tconst')
merging_df = merging_df.drop(columns=['knownForTitles'])
merging_df
# Out:
#                  primaryName birthYear deathYear  \
# 0               Fred Astaire      1899      1987
# 1               Fred Astaire      1899      1987
# 2               Fred Astaire      1899      1987
# 3               Fred Astaire      1899      1987
# 4              Lauren Bacall      1924      2014
# ...                      ...       ...       ...
# 22192036   Romeo del Rosario      <NA>      <NA>
# 22192037   Romeo del Rosario      <NA>      <NA>
# 22192038   Romeo del Rosario      <NA>      <NA>
# 22192039  Harikrishnan Rajan      <NA>      <NA>
# 22192040         Aayush Nair      <NA>      <NA>
#
#                             primaryProfession      tconst titleType  \
# 0                actor,miscellaneous,producer   tt0072308     movie
# 1                actor,miscellaneous,producer   tt0050419     movie
# 2                actor,miscellaneous,producer   tt0053137     movie
# 3                actor,miscellaneous,producer   tt0027125     movie
# 4          actress,soundtrack,archive_footage   tt0037382     movie
# ...                                       ...         ...       ...
# 22192036  animation_department,art_department  tt11657662     movie
# 22192037  animation_department,art_department  tt14069590  tvSeries
# 22192038  animation_department,art_department   tt2455546  tvSeries
# 22192039                      cinematographer   tt8736744     short
# 22192040                      cinematographer   tt8736744     short
#
#                                 primaryTitle  \
# 0                       The Towering Inferno
# 1                                 Funny Face
# 2                               On the Beach
# 3                                    Top Hat
# 4                       To Have and Have Not
# ...                                      ...
# 22192036  The Witcher: Nightmare of the Wolf
# 22192037                Dota: Dragon's Blood
# 22192038                   Avengers Assemble
# 22192039                 Mirage The Last Men
# 22192040                 Mirage The Last Men
#
#                                originalTitle isAdult startYear endYear  \
# 0                       The Towering Inferno   False      1974    <NA>
# 1                                 Funny Face   False      1957    <NA>
# 2                               On the Beach   False      1959    <NA>
# 3                                    Top Hat   False      1935    <NA>
# 4                       To Have and Have Not   False      1944    <NA>
# ...                                      ...     ...       ...     ...
# 22192036  The Witcher: Nightmare of the Wolf   False      2021    <NA>
# 22192037                Dota: Dragon's Blood   False      2021    2022
# 22192038                   Avengers Assemble   False      2012    2019
# 22192039                 Mirage The Last Men   False      2018    <NA>
# 22192040                 Mirage The Last Men   False      2018    <NA>
#
#          runtimeMinutes                      genres
# 0                   165       Action,Drama,Thriller
# 1                   103      Comedy,Musical,Romance
# 2                   134        Drama,Romance,Sci-Fi
# 3                   101      Comedy,Musical,Romance
# 4                   100  Adventure,Comedy,Film-Noir
# ...                 ...                         ...
# 22192036             83  Action,Adventure,Animation
# 22192037             25  Action,Adventure,Animation
# 22192038             23  Action,Adventure,Animation
# 22192039           <NA>                 Drama,Short
# 22192040           <NA>                 Drama,Short
#
# [22192041 rows x 13 columns]

# %%
final_df = pd.merge(merging_df, df3, on='tconst')

# %%
final_df.head()
# Out:
#      primaryName birthYear deathYear                   primaryProfession  \
# 0   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 1   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 2   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 3   Fred Astaire      1899      1987        actor,miscellaneous,producer
# 4  Lauren Bacall      1924      2014  actress,soundtrack,archive_footage
#
#       tconst titleType          primaryTitle         originalTitle isAdult  \
# 0  tt0072308     movie  The Towering Inferno  The Towering Inferno   False
# 1  tt0050419     movie            Funny Face            Funny Face   False
# 2  tt0053137     movie          On the Beach          On the Beach   False
# 3  tt0027125     movie               Top Hat               Top Hat   False
# 4  tt0037382     movie  To Have and Have Not  To Have and Have Not   False
#
#   startYear endYear runtimeMinutes                      genres  averageRating  \
# 0      1974    <NA>            165       Action,Drama,Thriller            7.0
# 1      1957    <NA>            103      Comedy,Musical,Romance            7.0
# 2      1959    <NA>            134        Drama,Romance,Sci-Fi            7.1
# 3      1935    <NA>            101      Comedy,Musical,Romance            7.7
# 4      1944    <NA>            100  Adventure,Comedy,Film-Noir            7.8
#
#    numVotes
# 0     48391
# 1     33119
# 2     14451
# 3     20748
# 4     38063

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14144467 entries, 0 to 14144466
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   primaryName        object
#  1   birthYear          object
#  2   deathYear          object
#  3   primaryProfession  object
#  4   tconst             object
#  5   titleType          object
#  6   primaryTitle       object
#  7   originalTitle      object
#  8   isAdult            object
#  9   startYear          object
#  10  endYear            object
#  11  runtimeMinutes     object
#  12  genres             object
#  13  averageRating      float64
#  14  numVotes           int64
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.6+ GB

# %%
final_df.isnull().sum()
# Out:
# primaryName                 0
# birthYear            12575731
# deathYear            13608432
# primaryProfession     1155151
# tconst                      0
# titleType                   0
# primaryTitle                0
# originalTitle               0
# isAdult                     0
# startYear                1279
# endYear              11806724
# runtimeMinutes        2334748
# genres                 156925
# averageRating               0
# numVotes                    0
# dtype: int64

# %%
df4.head()
# Out:
#         review_date   movie_id    user_id  is_spoiler  \
# 0  10 February 2006  tt0111161  ur1898687        True
# 1  6 September 2000  tt0111161  ur0842118        True
# 2     3 August 2001  tt0111161  ur1285640        True
# 3  1 September 2002  tt0111161  ur1003471        True
# 4       20 May 2004  tt0111161  ur0226855        True
#
#                                          review_text  rating  \
# 0  In its Oscar year, Shawshank Redemption (writt...      10
# 1  The Shawshank Redemption is without a doubt on...      10
# 2  I believe that this film is the best story eve...       8
# 3  **Yes, there are SPOILERS here**This film has ...      10
# 4  At the heart of this extraordinary movie is a ...       8
#
#                                   review_summary
# 0  A classic piece of unforgettable film-making.
# 1     Simply amazing. The best film of the 90's.
# 2               The best story ever told on film
# 3                     Busy dying or busy living?
# 4         Great story, wondrously told and acted

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 573913 entries, 0 to 573912
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   review_date     573913 non-null  object
#  1   movie_id        573913 non-null  object
#  2   user_id         573913 non-null  object
#  3   is_spoiler      573913 non-null  bool
#  4   review_text     573913 non-null  object
#  5   rating          573913 non-null  int64
#  6   review_summary  573913 non-null  object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 31.2+ MB

# %%
df4.rename(columns={'rating': 'review_rating'}, inplace=True)

# %%
df5.head()
# Out:
#     movie_id                                       plot_summary  duration  \
# 0  tt0105112  Former CIA analyst, Jack Ryan is in England wi...  1h 57min
# 1  tt1204975  Billy (Michael Douglas), Paddy (Robert De Niro...  1h 45min
# 2  tt0243655  The setting is Camp Firewood, the year 1981. I...  1h 37min
# 3  tt0040897  Fred C. Dobbs and Bob Curtin, both down on the...   2h 6min
# 4  tt0126886  Tracy Flick is running unopposed for this year...  1h 43min
#
#                          genre  rating release_date  \
# 0           [Action, Thriller]     6.9   1992-06-05
# 1                     [Comedy]     6.6   2013-11-01
# 2            [Comedy, Romance]     6.7   2002-04-11
# 3  [Adventure, Drama, Western]     8.3   1948-01-24
# 4     [Comedy, Drama, Romance]     7.3   1999-05-07
#
#                                        plot_synopsis
# 0  Jack Ryan (Ford) is on a "working vacation" in...
# 1  Four boys around the age of 10 are friends in ...
# 2
# 3  Fred Dobbs (Humphrey Bogart) and Bob Curtin (T...
# 4  Jim McAllister (Matthew Broderick) is a much-a...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1572 entries, 0 to 1571
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       1572 non-null   object
#  1   plot_summary   1572 non-null   object
#  2   duration       1572 non-null   object
#  3   genre          1572 non-null   object
#  4   rating         1572 non-null   float64
#  5   release_date   1572 non-null   object
#  6   plot_synopsis  1572 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 98.2+ KB

# %%
df5.rename(columns={'rating': 'overall_rating'}, inplace=True)

# %%
reviews_df = pd.merge(df4, df5, on='movie_id')
reviews_df.head()
# Out:
#         review_date   movie_id    user_id  is_spoiler  \
# 0  10 February 2006  tt0111161  ur1898687        True
# 1  6 September 2000  tt0111161  ur0842118        True
# 2     3 August 2001  tt0111161  ur1285640        True
# 3  1 September 2002  tt0111161  ur1003471        True
# 4       20 May 2004  tt0111161  ur0226855        True
#
#                                          review_text  review_rating  \
# 0  In its Oscar year, Shawshank Redemption (writt...             10
# 1  The Shawshank Redemption is without a doubt on...             10
# 2  I believe that this film is the best story eve...              8
# 3  **Yes, there are SPOILERS here**This film has ...             10
# 4  At the heart of this extraordinary movie is a ...              8
#
#                                   review_summary  \
# 0  A classic piece of unforgettable film-making.
# 1     Simply amazing. The best film of the 90's.
# 2               The best story ever told on film
# 3                     Busy dying or busy living?
# 4         Great story, wondrously told and acted
#
#                                         plot_summary  duration  \
# 0  Chronicles the experiences of a formerly succe...  2h 22min
# 1  Chronicles the experiences of a formerly succe...  2h 22min
# 2  Chronicles the experiences of a formerly succe...  2h 22min
# 3  Chronicles the experiences of a formerly succe...  2h 22min
# 4  Chronicles the experiences of a formerly succe...  2h 22min
#
#             genre  overall_rating release_date  \
# 0  [Crime, Drama]             9.3   1994-10-14
# 1  [Crime, Drama]             9.3   1994-10-14
# 2  [Crime, Drama]             9.3   1994-10-14
# 3  [Crime, Drama]             9.3   1994-10-14
# 4  [Crime, Drama]             9.3   1994-10-14
#
#                                        plot_synopsis
# 0  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 2  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 3  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 4  In 1947, Andy Dufresne (Tim Robbins), a banker...

# %%
reviews_df['genres'] = reviews_df['genre'].apply(lambda x: ', '.join(x))
reviews_df = reviews_df.drop(columns=['genre'])
reviews_df.head()
# Out:
#         review_date   movie_id    user_id  is_spoiler  \
# 0  10 February 2006  tt0111161  ur1898687        True
# 1  6 September 2000  tt0111161  ur0842118        True
# 2     3 August 2001  tt0111161  ur1285640        True
# 3  1 September 2002  tt0111161  ur1003471        True
# 4       20 May 2004  tt0111161  ur0226855        True
#
#                                          review_text  review_rating  \
# 0  In its Oscar year, Shawshank Redemption (writt...             10
# 1  The Shawshank Redemption is without a doubt on...             10
# 2  I believe that this film is the best story eve...              8
# 3  **Yes, there are SPOILERS here**This film has ...             10
# 4  At the heart of this extraordinary movie is a ...              8
#
#                                   review_summary  \
# 0  A classic piece of unforgettable film-making.
# 1     Simply amazing. The best film of the 90's.
# 2               The best story ever told on film
# 3                     Busy dying or busy living?
# 4         Great story, wondrously told and acted
#
#                                         plot_summary  duration  \
# 0  Chronicles the experiences of a formerly succe...  2h 22min
# 1  Chronicles the experiences of a formerly succe...  2h 22min
# 2  Chronicles the experiences of a formerly succe...  2h 22min
# 3  Chronicles the experiences of a formerly succe...  2h 22min
# 4  Chronicles the experiences of a formerly succe...  2h 22min
#
#    overall_rating release_date  \
# 0             9.3   1994-10-14
# 1             9.3   1994-10-14
# 2             9.3   1994-10-14
# 3             9.3   1994-10-14
# 4             9.3   1994-10-14
#
#                                        plot_synopsis        genres
# 0  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 2  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 3  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 4  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama

# %%
reviews_df.rename(columns={'movie_id': 'title_id'}, inplace=True)
reviews_df.head()
# Out:
#         review_date   title_id    user_id  is_spoiler  \
# 0  10 February 2006  tt0111161  ur1898687        True
# 1  6 September 2000  tt0111161  ur0842118        True
# 2     3 August 2001  tt0111161  ur1285640        True
# 3  1 September 2002  tt0111161  ur1003471        True
# 4       20 May 2004  tt0111161  ur0226855        True
#
#                                          review_text  review_rating  \
# 0  In its Oscar year, Shawshank Redemption (writt...             10
# 1  The Shawshank Redemption is without a doubt on...             10
# 2  I believe that this film is the best story eve...              8
# 3  **Yes, there are SPOILERS here**This film has ...             10
# 4  At the heart of this extraordinary movie is a ...              8
#
#                                   review_summary  \
# 0  A classic piece of unforgettable film-making.
# 1     Simply amazing. The best film of the 90's.
# 2               The best story ever told on film
# 3                     Busy dying or busy living?
# 4         Great story, wondrously told and acted
#
#                                         plot_summary  duration  \
# 0  Chronicles the experiences of a formerly succe...  2h 22min
# 1  Chronicles the experiences of a formerly succe...  2h 22min
# 2  Chronicles the experiences of a formerly succe...  2h 22min
# 3  Chronicles the experiences of a formerly succe...  2h 22min
# 4  Chronicles the experiences of a formerly succe...  2h 22min
#
#    overall_rating release_date  \
# 0             9.3   1994-10-14
# 1             9.3   1994-10-14
# 2             9.3   1994-10-14
# 3             9.3   1994-10-14
# 4             9.3   1994-10-14
#
#                                        plot_synopsis        genres
# 0  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 1  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 2  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 3  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama
# 4  In 1947, Andy Dufresne (Tim Robbins), a banker...  Crime, Drama

# %%
final_df.rename(columns={'movie_id': 'title_id'}, inplace=True)
final_df
# Out:
#                 primaryName birthYear deathYear  \
# 0              Fred Astaire      1899      1987
# 1              Fred Astaire      1899      1987
# 2              Fred Astaire      1899      1987
# 3              Fred Astaire      1899      1987
# 4             Lauren Bacall      1924      2014
# ...                     ...       ...       ...
# 14144462      Sambit Mishra      <NA>      <NA>
# 14144463      Sambit Mishra      <NA>      <NA>
# 14144464  Romeo del Rosario      <NA>      <NA>
# 14144465  Romeo del Rosario      <NA>      <NA>
# 14144466  Romeo del Rosario      <NA>      <NA>
#
#                             primaryProfession    title_id titleType  \
# 0                actor,miscellaneous,producer   tt0072308     movie
# 1                actor,miscellaneous,producer   tt0050419     movie
# 2                actor,miscellaneous,producer   tt0053137     movie
# 3                actor,miscellaneous,producer   tt0027125     movie
# 4          actress,soundtrack,archive_footage   tt0037382     movie
# ...                                       ...         ...       ...
# 14144462                      writer,producer  tt10709066  tvSeries
# 14144463                      writer,producer  tt15134202  tvSeries
# 14144464  animation_department,art_department  tt11657662     movie
# 14144465  animation_department,art_department  tt14069590  tvSeries
# 14144466  animation_department,art_department   tt2455546  tvSeries
#
#                                 primaryTitle  \
# 0                       The Towering Inferno
# 1                                 Funny Face
# 2                               On the Beach
# 3                                    Top Hat
# 4                       To Have and Have Not
# ...                                      ...
# 14144462                       Tere Liye Bro
# 14144463                              Cartel
# 14144464  The Witcher: Nightmare of the Wolf
# 14144465                Dota: Dragon's Blood
# 14144466                   Avengers Assemble
#
#                                originalTitle isAdult startYear endYear  \
# 0                       The Towering Inferno   False      1974    <NA>
# 1                                 Funny Face   False      1957    <NA>
# 2                               On the Beach   False      1959    <NA>
# 3                                    Top Hat   False      1935    <NA>
# 4                       To Have and Have Not   False      1944    <NA>
# ...                                      ...     ...       ...     ...
# 14144462                       Tere Liye Bro   False      2017    2018
# 14144463                              Cartel   False      2021    2021
# 14144464  The Witcher: Nightmare of the Wolf   False      2021    <NA>
# 14144465                Dota: Dragon's Blood   False      2021    2022
# 14144466                   Avengers Assemble   False      2012    2019
#
#          runtimeMinutes                      genres  averageRating  numVotes
# 0                   165       Action,Drama,Thriller            7.0     48391
# 1                   103      Comedy,Musical,Romance            7.0     33119
# 2                   134        Drama,Romance,Sci-Fi            7.1     14451
# 3                   101      Comedy,Musical,Romance            7.7     20748
# 4                   100  Adventure,Comedy,Film-Noir            7.8     38063
# ...                 ...                         ...            ...       ...
# 14144462             22                       Drama            8.4        18
# 14144463           <NA>                Action,Drama            8.0      4272
# 14144464             83  Action,Adventure,Animation            7.2     50417
# 14144465             25  Action,Adventure,Animation            7.7     21791
# 14144466             23  Action,Adventure,Animation            7.0      8379
#
# [14144467 rows x 15 columns]

# %%
movie_df = pd.merge(reviews_df, final_df, on=['title_id', 'genres'])
movie_df
# Out:
#               review_date   title_id    user_id  is_spoiler  \
# 0            11 June 2001  tt0137523  ur0282760        True
# 1            11 June 2001  tt0137523  ur0282760        True
# 2            11 June 2001  tt0137523  ur0282760        True
# 3            11 June 2001  tt0137523  ur0282760        True
# 4            11 June 2001  tt0137523  ur0282760        True
# ...                   ...        ...        ...         ...
# 4747582  29 December 2013  tt0201265  ur0311809       False
# 4747583  29 December 2013  tt0201265  ur0311809       False
# 4747584  29 December 2013  tt0201265  ur0311809       False
# 4747585  29 December 2013  tt0201265  ur0311809       False
# 4747586  29 December 2013  tt0201265  ur0311809       False
#
#                                                review_text  review_rating  \
# 0        Please.This is a dismal movie.  I'm going to s...              1
# 1        Please.This is a dismal movie.  I'm going to s...              1
# 2        Please.This is a dismal movie.  I'm going to s...              1
# 3        Please.This is a dismal movie.  I'm going to s...              1
# 4        Please.This is a dismal movie.  I'm going to s...              1
# ...                                                    ...            ...
# 4747582  It's a well known fact that Christmas party's ...              8
# 4747583  It's a well known fact that Christmas party's ...              8
# 4747584  It's a well known fact that Christmas party's ...              8
# 4747585  It's a well known fact that Christmas party's ...              8
# 4747586  It's a well known fact that Christmas party's ...              8
#
#                                            review_summary  \
# 0        The comparison to Clockwork Orange makes me puke
# 1        The comparison to Clockwork Orange makes me puke
# 2        The comparison to Clockwork Orange makes me puke
# 3        The comparison to Clockwork Orange makes me puke
# 4        The comparison to Clockwork Orange makes me puke
# ...                                                   ...
# 4747582    Modern society masked as Christmas catastrophe
# 4747583    Modern society masked as Christmas catastrophe
# 4747584    Modern society masked as Christmas catastrophe
# 4747585    Modern society masked as Christmas catastrophe
# 4747586    Modern society masked as Christmas catastrophe
#
#                                               plot_summary  duration  \
# 0        A nameless first person narrator (Edward Norto...  2h 19min
# 1        A nameless first person narrator (Edward Norto...  2h 19min
# 2        A nameless first person narrator (Edward Norto...  2h 19min
# 3        A nameless first person narrator (Edward Norto...  2h 19min
# 4        A nameless first person narrator (Edward Norto...  2h 19min
# ...                                                    ...       ...
# 4747582  In what has to be one of the worst ideas in Ch...  1h 35min
# 4747583  In what has to be one of the worst ideas in Ch...  1h 35min
# 4747584  In what has to be one of the worst ideas in Ch...  1h 35min
# 4747585  In what has to be one of the worst ideas in Ch...  1h 35min
# 4747586  In what has to be one of the worst ideas in Ch...  1h 35min
#
#          overall_rating  ...  \
# 0                   8.8  ...
# 1                   8.8  ...
# 2                   8.8  ...
# 3                   8.8  ...
# 4                   8.8  ...
# ...                 ...  ...
# 4747582             6.8  ...
# 4747583             6.8  ...
# 4747584             6.8  ...
# 4747585             6.8  ...
# 4747586             6.8  ...
#
#                                          primaryProfession titleType  \
# 0                                 producer,actor,executive     movie
# 1                                actress,director,producer     movie
# 2                              music_artist,actor,producer     movie
# 3                                    actor,producer,writer     movie
# 4        visual_effects,animation_department,art_depart...     movie
# ...                                                    ...       ...
# 4747582                                      miscellaneous     movie
# 4747583                                            actress     movie
# 4747584                                              actor     movie
# 4747585                                              actor     movie
# 4747586                                              actor     movie
#
#               primaryTitle                   originalTitle isAdult startYear  \
# 0               Fight Club                      Fight Club   False      1999
# 1               Fight Club                      Fight Club   False      1999
# 2               Fight Club                      Fight Club   False      1999
# 3               Fight Club                      Fight Club   False      1999
# 4               Fight Club                      Fight Club   False      1999
# ...                    ...                             ...     ...       ...
# 4747582  In Bed with Santa  Tomten är far till alla barnen   False      1999
# 4747583  In Bed with Santa  Tomten är far till alla barnen   False      1999
# 4747584  In Bed with Santa  Tomten är far till alla barnen   False      1999
# 4747585  In Bed with Santa  Tomten är far till alla barnen   False      1999
# 4747586  In Bed with Santa  Tomten är far till alla barnen   False      1999
#
#         endYear runtimeMinutes averageRating numVotes
# 0          <NA>            139           8.8  2331118
# 1          <NA>            139           8.8  2331118
# 2          <NA>            139           8.8  2331118
# 3          <NA>            139           8.8  2331118
# 4          <NA>            139           8.8  2331118
# ...         ...            ...           ...      ...
# 4747582    <NA>             95           6.9     8673
# 4747583    <NA>             95           6.9     8673
# 4747584    <NA>             95           6.9     8673
# 4747585    <NA>             95           6.9     8673
# 4747586    <NA>             95           6.9     8673
#
# [4747587 rows x 26 columns]

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4747587 entries, 0 to 4747586
# Data columns (total 26 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   review_date        object
#  1   title_id           object
#  2   user_id            object
#  3   is_spoiler         bool
#  4   review_text        object
#  5   review_rating      int64
#  6   review_summary     object
#  7   plot_summary       object
#  8   duration           object
#  9   overall_rating     float64
#  10  release_date       object
#  11  plot_synopsis      object
#  12  genres             object
#  13  primaryName        object
#  14  birthYear          object
#  15  deathYear          object
#  16  primaryProfession  object
#  17  titleType          object
#  18  primaryTitle       object
#  19  originalTitle      object
#  20  isAdult            object
#  21  startYear          object
#  22  endYear            object
#  23  runtimeMinutes     object
#  24  averageRating      float64
#  25  numVotes           int64
# dtypes: bool(1), float64(2), int64(2), object(21)
# memory usage: 910.1+ MB

# %%
movie_df.isnull().sum()
# Out:
# review_date                0
# title_id                   0
# user_id                    0
# is_spoiler                 0
# review_text                0
# review_rating              0
# review_summary             0
# plot_summary               0
# duration                   0
# overall_rating             0
# release_date               0
# plot_synopsis              0
# genres                     0
# primaryName                0
# birthYear            3712112
# deathYear            4506705
# primaryProfession        420
# titleType                  0
# primaryTitle               0
# originalTitle              0
# isAdult                    0
# startYear                  0
# endYear              4747587
# runtimeMinutes             0
# averageRating              0
# numVotes                   0
# dtype: int64

# %% [markdown]
# ## Chunking

# %%
# !pip3 uninstall torch

# %%
import utils
from utils import chunkDocs, langDetect, wordCloud
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 import utils
#       2 from utils import chunkDocs, langDetect, wordCloud
#
# File ~\Documents\Software-Udvikling\AI\AI_exam\utils.py:1
# ----> 1 import spacy
#       2 import langdetect
#       3 from wordcloud import WordCloud
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\thinc\config.py:5
#       2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
# ----> 5 from .types import Decorator
#       8 class registry(confection.registry):
#       9     # fmt: off
#      10     optimizers: Decorator = catalogue.create("thinc", "optimizers", entry_points=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\thinc\types.py:25
#       4 from typing import (
#       5     Any,
#       6     Callable,
#    (...)
#      20     overload,
#      21 )
#      23 import numpy
# ---> 25 from .compat import cupy, has_cupy
#      27 if has_cupy:
#      28     get_array_module = cupy.get_array_module
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\thinc\compat.py:35
#      31     has_cupy_gpu = False
#      34 try:  # pragma: no cover
# ---> 35     import torch
#      36     import torch.utils.dlpack
#      38     has_torch = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "C:\Users\Caroline\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\lib\shm.dll" or one of its dependencies.
